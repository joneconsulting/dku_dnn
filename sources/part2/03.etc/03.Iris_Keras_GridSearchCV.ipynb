# %%
import numpy as np
from sklearn import datasets, preprocessing
from sklearn.model_selection import train_test_split
from sklearn.model_selection import GridSearchCV
from keras.models import Sequential
# from keras.layers.core import Dense, Activation
from tensorflow.keras.layers import Input, Conv2D, Dense, Flatten, Dropout
from tensorflow.keras.models import Model
# from keras.utils import np_utils
# from keras import backend as K
# from keras.wrappers.scikit_learn import KerasClassifier
# Keras -> TF2.0 
from tensorflow.keras.utils import to_categorical
from tensorflow.keras import backend as K
from tensorflow.keras.wrappers.scikit_learn import KerasClassifier
# Out:
# Using TensorFlow backend.

# %%
iris = datasets.load_iris()
x = preprocessing.scale(iris.data)
y = to_categorical(iris.target)
x_train, x_test, y_train, y_test = train_test_split(x, y, train_size  = 0.7)
num_classes = y_test.shape[1]

# x = [[0,0],[1,0],[0,1],[1,1]]
# x_train = [[0,0],[1,0],[0,1],[1,1]]
# y_train = [0,0,0,1]
# print(x_train)
# num_classes = 2

# %%
def iris_model(activation="relu", optimizer="adam", out_dim=100):
#     model = Sequential()
#     model.add(Dense(out_dim, input_dim=4, activation=activation))
#     model.add(Dense(out_dim, activation=activation))
#     model.add(Dense(num_classes, activation="softmax"))
#     model.compile(loss='categorical_crossentropy', optimizer=optimizer, metrics=['accuracy'])
    i = Input(4)
    x = Dense(out_dim, activation=activation)(i)
    x = Dense(out_dim, activation=activation)(x)
    x = Dense(num_classes, activation="softmax")(x)
    model = Model(i, x)
    model.compile(loss='categorical_crossentropy', optimizer=optimizer, metrics=['accuracy'])
    print("actiation=", activation)
    return model

# %%
activation = ["relu", "sigmoid"]
optimizer = ["adam", "adagrad"]
out_dim = [100, 200]
nb_epoch = [10, 25]
batch_size = [5, 10]
# activation = ["relu"]
# nb_epoch = [3]
# batch_size = [5]

# %%
model = KerasClassifier(build_fn=iris_model, verbose=1)
param_grid = dict(activation=activation, 
                  optimizer=optimizer, 
                  out_dim=out_dim, 
                  nb_epoch=nb_epoch, 
                  batch_size=batch_size)
# param_grid = dict(activation=activation, 
#                   nb_epoch=nb_epoch, 
#                   batch_size=batch_size)
grid = GridSearchCV(estimator=model, param_grid=param_grid, cv=2)

# %%
grid_result = grid.fit(x_train, y_train)
# Out:
# actiation= relu
# 11/11 [==============================] - 0s 618us/step - loss: 0.9713 - accuracy: 0.6538
# 11/11 [==============================] - 0s 550us/step - loss: 0.8252 - accuracy: 0.8868
# actiation= relu
# 11/11 [==============================] - 0s 658us/step - loss: 0.9594 - accuracy: 0.6415
# 11/11 [==============================] - 0s 555us/step - loss: 0.7975 - accuracy: 0.6923
# actiation= relu
# 11/11 [==============================] - 0s 1ms/step - loss: 0.8220 - accuracy: 0.6923
# 11/11 [==============================] - 0s 512us/step - loss: 0.5759 - accuracy: 0.8302
# actiation= relu
# 11/11 [==============================] - 0s 768us/step - loss: 0.9610 - accuracy: 0.5283
# 11/11 [==============================] - 0s 479us/step - loss: 0.6961 - accuracy: 0.6731
# actiation= relu
# 11/11 [==============================] - 0s 685us/step - loss: 1.1391 - accuracy: 0.4038
# 11/11 [==============================] - 0s 523us/step - loss: 1.1094 - accuracy: 0.3585
# actiation= relu
# 11/11 [==============================] - 0s 573us/step - loss: 1.2550 - accuracy: 0.3585
# 11/11 [==============================] - 0s 523us/step - loss: 1.2607 - accuracy: 0.2308
# actiation= relu
# 11/11 [==============================] - 0s 618us/step - loss: 1.0582 - accuracy: 0.5385
# actiation= sigmoid
# 6/6 [==============================] - 0s 754us/step - loss: 1.0831 - accuracy: 0.4528
# 6/6 [==============================] - 0s 585us/step - loss: 1.1758 - accuracy: 0.3077
# actiation= sigmoid
# 6/6 [==============================] - 0s 764us/step - loss: 1.1788 - accuracy: 0.3654
# 6/6 [==============================] - 0s 582us/step - loss: 1.1256 - accuracy: 0.2830
# actiation= sigmoid
# 6/6 [==============================] - 0s 915us/step - loss: 1.0843 - accuracy: 0.4151
# 6/6 [==============================] - 0s 621us/step - loss: 1.1609 - accuracy: 0.3077
# actiation= sigmoid
# 6/6 [==============================] - 0s 769us/step - loss: 1.2256 - accuracy: 0.2692
# 6/6 [==============================] - 0s 570us/step - loss: 1.2891 - accuracy: 0.2830
# actiation= sigmoid
# 6/6 [==============================] - 0s 812us/step - loss: 1.3098 - accuracy: 0.4528
# 6/6 [==============================] - 0s 656us/step - loss: 1.0694 - accuracy: 0.3654
# actiation= sigmoid
# 6/6 [==============================] - 0s 727us/step - loss: 1.8094 - accuracy: 0.3269
# 6/6 [==============================] - 0s 811us/step - loss: 1.8891 - accuracy: 0.2642
# actiation= sigmoid
# 6/6 [==============================] - 0s 664us/step - loss: 1.0758 - accuracy: 0.4528
# 6/6 [==============================] - 0s 594us/step - loss: 1.1121 - accuracy: 0.3077
# actiation= sigmoid
# 6/6 [==============================] - 0s 754us/step - loss: 1.2591 - accuracy: 0.3654
# 6/6 [==============================] - 0s 795us/step - loss: 1.4016 - accuracy: 0.2830
# actiation= sigmoid
# 6/6 [==============================] - 0s 716us/step - loss: 1.2909 - accuracy: 0.4151
# 6/6 [==============================] - 0s 574us/step - loss: 1.3944 - accuracy: 0.3077
# actiation= relu
# 21/21 [==============================] - 0s 688us/step - loss: 0.6510 - accuracy: 0.7619

# %%
print (grid_result.best_score_)
print (grid_result.best_params_)
# Out:
# 0.8281930387020111
# {'activation': 'relu', 'batch_size': 5, 'nb_epoch': 25, 'optimizer': 'adam', 'out_dim': 200}

# %%
# grid_eval = grid.predict(x_test)
# def y_binary(i):
#     if   i == 0: return [1, 0, 0]
#     elif i == 1: return [0, 1, 0]
#     elif i == 2: return [0, 0, 1]
# y_eval = np.array([y_binary(i) for i in grid_eval])
# accuracy = (y_eval == y_test)
# print (np.count_nonzero(accuracy == True) / (accuracy.shape[0] * accuracy.shape[1]))

# %%
model = iris_model(activation=grid_result.best_params_['activation'], 
                   optimizer=grid_result.best_params_['optimizer'], 
                   out_dim=grid_result.best_params_['out_dim'])
model.summary()
# Out:
# actiation= relu
# Model: "functional_137"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_69 (InputLayer)        [(None, 4)]               0
# _________________________________________________________________
# dense_204 (Dense)            (None, 200)               1000
# _________________________________________________________________
# dense_205 (Dense)            (None, 200)               40200
# _________________________________________________________________
# dense_206 (Dense)            (None, 3)                 603
# =================================================================
# Total params: 41,803
# Trainable params: 41,803
# Non-trainable params: 0
# _________________________________________________________________
