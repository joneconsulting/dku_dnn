# %%
# !pip install --upgrade tensorboard==2.2.0
# !pip install --upgrade tensorflow-estimator==2.2.0rc0

# %%
# !pip install -q tensorflow-gpu

# %%
import tensorflow as tf
print(tf.__version__)
# Out:
# 2.8.0

# %%
from tensorflow.keras.layers import Input, Dense
from tensorflow.keras.models import Model
from tensorflow.keras.optimizers import SGD, Adam

import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
# make the original data
series = np.sin(0.1 * np.arange(200)) #+ np.random.randn(200) * 0.1

# plot it
plt.plot(series)
plt.show()

# %%
### build the dataset
# let's see if we can use T pas values to predict the next value
T =10
X = []
Y = []
for t in range(len(series) - T):
  x = series[t:t+T]
  X.append(x)
  y = series[t+T]
  Y.append(y)

X = np.array(X).reshape(-1, T)
Y = np.array(Y)
N = len(X)
print("X.shape:", X.shape, ", Y.shape:", Y.shape)
# Out:
# X.shape: (190, 10) , Y.shape: (190,)

# %%
### try autoregressive linear model
i = Input(shape=(T,))
x = Dense(1)(i)
# x = Dense(1)(i)
model = Model(i, x)
model.compile(loss='mse', optimizer=Adam(lr=0.1))

# train the RNN
r = model.fit(X[:-N//2], Y[:-N//2], epochs=80, validation_data=(X[-N//2:], Y[-N//2:]))
# Out:
# Epoch 1/80
# 2022-03-10 09:13:36.998315: I tensorflow/core/platform/cpu_feature_guard.cc:151] This TensorFlow binary is optimized with oneAPI Deep Neural Network Library (oneDNN) to use the following CPU instructions in performance-critical operations:  AVX2 FMA
# To enable them in other operations, rebuild TensorFlow with the appropriate compiler flags.
# /opt/anaconda3/lib/python3.8/site-packages/keras/optimizer_v2/adam.py:105: UserWarning: The `lr` argument is deprecated, use `learning_rate` instead.
#   super(Adam, self).__init__(name, **kwargs)
# 3/3 [==============================] - 0s 45ms/step - loss: 0.8810 - val_loss: 0.6695
# Epoch 2/80
# 3/3 [==============================] - 0s 9ms/step - loss: 0.4662 - val_loss: 0.2236
# Epoch 3/80
# 3/3 [==============================] - 0s 10ms/step - loss: 0.2044 - val_loss: 0.1369
# Epoch 4/80
# 3/3 [==============================] - 0s 10ms/step - loss: 0.0601 - val_loss: 0.0141
# Epoch 5/80
# 3/3 [==============================] - 0s 10ms/step - loss: 0.0481 - val_loss: 0.0452
# Epoch 6/80
# 3/3 [==============================] - 0s 8ms/step - loss: 0.0447 - val_loss: 0.0633
# Epoch 7/80
# 3/3 [==============================] - 0s 10ms/step - loss: 0.0714 - val_loss: 0.0737
# Epoch 8/80
# 3/3 [==============================] - 0s 9ms/step - loss: 0.0594 - val_loss: 0.0698
# Epoch 9/80
# 3/3 [==============================] - 0s 9ms/step - loss: 0.0503 - val_loss: 0.0360
# Epoch 10/80
# 3/3 [==============================] - 0s 10ms/step - loss: 0.0200 - val_loss: 0.0119
# Epoch 11/80
# 3/3 [==============================] - 0s 9ms/step - loss: 0.0102 - val_loss: 0.0036
# Epoch 12/80
# 3/3 [==============================] - 0s 10ms/step - loss: 0.0020 - val_loss: 0.0046
# Epoch 13/80
# 3/3 [==============================] - 0s 10ms/step - loss: 0.0059 - val_loss: 0.0061
# Epoch 14/80
# 3/3 [==============================] - 0s 9ms/step - loss: 0.0072 - val_loss: 0.0087
# Epoch 15/80
# 3/3 [==============================] - 0s 10ms/step - loss: 0.0082 - val_loss: 0.0058
# Epoch 16/80
# 3/3 [==============================] - 0s 10ms/step - loss: 0.0049 - val_loss: 0.0035
# Epoch 17/80
# 3/3 [==============================] - 0s 11ms/step - loss: 0.0022 - val_loss: 0.0013
# Epoch 18/80
# 3/3 [==============================] - 0s 8ms/step - loss: 9.5269e-04 - val_loss: 7.7931e-04
# Epoch 19/80
# 3/3 [==============================] - 0s 10ms/step - loss: 5.1361e-04 - val_loss: 0.0011
# Epoch 20/80
# 3/3 [==============================] - 0s 10ms/step - loss: 0.0012 - val_loss: 0.0016
# Epoch 21/80
# 3/3 [==============================] - 0s 8ms/step - loss: 0.0014 - val_loss: 0.0014
# Epoch 22/80
# 3/3 [==============================] - 0s 9ms/step - loss: 0.0011 - val_loss: 7.3630e-04
# Epoch 23/80
# 3/3 [==============================] - 0s 9ms/step - loss: 4.1821e-04 - val_loss: 1.5072e-04
# Epoch 24/80
# 3/3 [==============================] - 0s 9ms/step - loss: 1.9328e-04 - val_loss: 1.4989e-04
# Epoch 25/80
# 3/3 [==============================] - 0s 10ms/step - loss: 1.0575e-04 - val_loss: 2.6147e-04
# Epoch 26/80
# 3/3 [==============================] - 0s 10ms/step - loss: 2.6353e-04 - val_loss: 2.2798e-04
# Epoch 27/80
# 3/3 [==============================] - 0s 9ms/step - loss: 2.7279e-04 - val_loss: 1.5780e-04
# Epoch 28/80
# 3/3 [==============================] - 0s 10ms/step - loss: 1.3482e-04 - val_loss: 9.4703e-05
# Epoch 29/80
# 3/3 [==============================] - 0s 10ms/step - loss: 6.6204e-05 - val_loss: 5.2911e-05
# Epoch 30/80
# 3/3 [==============================] - 0s 8ms/step - loss: 3.5280e-05 - val_loss: 2.0553e-05
# Epoch 31/80
# 3/3 [==============================] - 0s 9ms/step - loss: 4.5316e-05 - val_loss: 9.6265e-05
# Epoch 32/80
# 3/3 [==============================] - 0s 9ms/step - loss: 5.2713e-05 - val_loss: 5.5873e-05
# Epoch 33/80
# 3/3 [==============================] - 0s 9ms/step - loss: 4.4457e-05 - val_loss: 1.7323e-05
# Epoch 34/80
# 3/3 [==============================] - 0s 9ms/step - loss: 2.3235e-05 - val_loss: 4.1203e-06
# Epoch 35/80
# 3/3 [==============================] - 0s 10ms/step - loss: 5.9021e-06 - val_loss: 1.3008e-05
# Epoch 36/80
# 3/3 [==============================] - 0s 9ms/step - loss: 8.7479e-06 - val_loss: 1.5340e-05
# Epoch 37/80
# 3/3 [==============================] - 0s 9ms/step - loss: 1.6269e-05 - val_loss: 9.3603e-06
# Epoch 38/80
# 3/3 [==============================] - 0s 10ms/step - loss: 1.
80
# 3/3 [==============================] - 0s 9ms/step - loss: 1.0630e-09 - val_loss: 1.7520e-09
# Epoch 72/80
# 3/3 [==============================] - 0s 9ms/step - loss: 1.0148e-09 - val_loss: 1.4691e-09
# Epoch 73/80
# 3/3 [==============================] - 0s 9ms/step - loss: 8.9863e-10 - val_loss: 1.5709e-09
# Epoch 74/80
# 3/3 [==============================] - 0s 9ms/step - loss: 9.6288e-10 - val_loss: 1.5217e-09
# Epoch 75/80
# 3/3 [==============================] - 0s 9ms/step - loss: 7.5348e-10 - val_loss: 4.9710e-10
# Epoch 76/80
# 3/3 [==============================] - 0s 9ms/step - loss: 4.3428e-10 - val_loss: 1.7516e-10
# Epoch 77/80
# 3/3 [==============================] - 0s 9ms/step - loss: 3.8222e-10 - val_loss: 1.2218e-10
# Epoch 78/80
# 3/3 [==============================] - 0s 9ms/step - loss: 3.1676e-10 - val_loss: 7.3925e-11
# Epoch 79/80
# 3/3 [==============================] - 0s 11ms/step - loss: 2.3998e-10 - val_loss: 2.7052e-12
# Epoch 80/80
# 3/3 [==============================] - 0s 10ms/step - loss: 1.6463e-10 - val_loss: 8.4434e-11

# %%
# Plot loss per iteration
plt.plot(r.history['loss'], label='loss')
plt.plot(r.history['val_loss'], label='val_loss')
plt.legend()

# %%
# "Wrong" forecast using true targets
validation_target = Y[-N//2:]
validation_predictions = []

# input of first vlidation input
i = -N//2

while len(validation_predictions) < len(validation_target):
  p = model.predict(X[i].reshape(1, -1))[0,0] # 1x1 array -> scalar
  i += 1

  # update the predictions list
  validation_predictions.append(p)

# %%
plt.plot(validation_target, label='forecast_target')
plt.plot(validation_predictions, label='forecast_prediction')
plt.legend()

# %%
# Forecast future values (use only self-predictions for making future predictions)
validation_target = Y[-N//2:]
validation_predictions = []

# last train input
last_x = X[-N//2] # 1-D array of length T, 10
# print(len(validation_target)) -> 95
# print(last_x) -> [A, B, ...]
print(last_x.reshape(1, -1)) #-> [[A, B, ...]]
print(model.predict(last_x.reshape(1, -1))[0,0])
while len(validation_predictions) < len(validation_target):
  p = model.predict(last_x.reshape(1, -1))[0,0] # 1x1 array -> scalar

  # update the predictions list
  validation_predictions.append(p)

  # make the new input
#   print("before:", last_x)
  last_x = np.roll(last_x, -1)
#   print("after:", last_x)
  last_x[-1] = p
# Out:
# [[-0.07515112 -0.17432678 -0.27176063 -0.36647913 -0.45753589 -0.54402111
#   -0.62507065 -0.69987469 -0.76768581 -0.82782647]]
# -0.8797007

# %%
plt.plot(validation_target, label='forecast_target')
plt.plot(validation_predictions, label='forecast_prediction')
plt.legend()

# %% [markdown]
# ## Noise examples

# %%
# make the original data (with noise)
series = np.sin(0.1 * np.arange(200)) + np.random.randn(200) * 0.1

# plot it
plt.plot(series)
plt.show()

# %%
### build the dataset
# let's see if we can use T pas values to predict the next value
T =10
X = []
Y = []
for t in range(len(series) - T):
  x = series[t:t+T]
  X.append(x)
  y = series[t+T]
  Y.append(y)

X = np.array(X).reshape(-1, T)
Y = np.array(Y)
N = len(X)
print("X.shape:", X.shape, ", Y.shape:", Y.shape, ", N:", N)
# Out:
# X.shape: (190, 10) , Y.shape: (190,) , N: 190

# %%
### try autoregressive linear model
i = Input(shape=(T,))
x = Dense(1)(i)
model = Model(i, x)
model.compile(loss='mse', optimizer=Adam(lr=0.1))

# train the RNN
r = model.fit(X[:-N//2], Y[:-N//2], epochs=80, validation_data=(X[-N//2:], Y[-N//2:]))
# Out:
# Epoch 1/80
# 1/3 [=========>....................] - ETA: 0s - loss: 2.4278
# /opt/anaconda3/lib/python3.8/site-packages/keras/optimizer_v2/adam.py:105: UserWarning: The `lr` argument is deprecated, use `learning_rate` instead.
#   super(Adam, self).__init__(name, **kwargs)
# 3/3 [==============================] - 0s 37ms/step - loss: 1.0466 - val_loss: 0.1308
# Epoch 2/80
# 3/3 [==============================] - 0s 10ms/step - loss: 0.4756 - val_loss: 0.5634
# Epoch 3/80
# 3/3 [==============================] - 0s 9ms/step - loss: 0.3697 - val_loss: 0.0931
# Epoch 4/80
# 3/3 [==============================] - 0s 9ms/step - loss: 0.1044 - val_loss: 0.1970
# Epoch 5/80
# 3/3 [==============================] - 0s 10ms/step - loss: 0.2978 - val_loss: 0.1610
# Epoch 6/80
# 3/3 [==============================] - 0s 9ms/step - loss: 0.1254 - val_loss: 0.0329
# Epoch 7/80
# 3/3 [==============================] - 0s 9ms/step - loss: 0.0606 - val_loss: 0.1177
# Epoch 8/80
# 3/3 [==============================] - 0s 8ms/step - loss: 0.1246 - val_loss: 0.0597
# Epoch 9/80
# 3/3 [==============================] - 0s 9ms/step - loss: 0.0385 - val_loss: 0.0576
# Epoch 10/80
# 3/3 [==============================] - 0s 9ms/step - loss: 0.0533 - val_loss: 0.0996
# Epoch 11/80
# 3/3 [==============================] - 0s 9ms/step - loss: 0.0599 - val_loss: 0.0353
# Epoch 12/80
# 3/3 [==============================] - 0s 8ms/step - loss: 0.0200 - val_loss: 0.0464
# Epoch 13/80
# 3/3 [==============================] - 0s 9ms/step - loss: 0.0383 - val_loss: 0.0502
# Epoch 14/80
# 3/3 [==============================] - 0s 9ms/step - loss: 0.0276 - val_loss: 0.0288
# Epoch 15/80
# 3/3 [==============================] - 0s 9ms/step - loss: 0.0196 - val_loss: 0.0358
# Epoch 16/80
# 3/3 [==============================] - 0s 8ms/step - loss: 0.0243 - val_loss: 0.0288
# Epoch 17/80
# 3/3 [==============================] - 0s 9ms/step - loss: 0.0177 - val_loss: 0.0295
# Epoch 18/80
# 3/3 [==============================] - 0s 9ms/step - loss: 0.0206 - val_loss: 0.0288
# Epoch 19/80
# 3/3 [==============================] - 0s 9ms/step - loss: 0.0167 - val_loss: 0.0284
# Epoch 20/80
# 3/3 [==============================] - 0s 10ms/step - loss: 0.0167 - val_loss: 0.0296
# Epoch 21/80
# 3/3 [==============================] - 0s 10ms/step - loss: 0.0169 - val_loss: 0.0265
# Epoch 22/80
# 3/3 [==============================] - 0s 9ms/step - loss: 0.0159 - val_loss: 0.0283
# Epoch 23/80
# 3/3 [==============================] - 0s 9ms/step - loss: 0.0166 - val_loss: 0.0264
# Epoch 24/80
# 3/3 [==============================] - 0s 10ms/step - loss: 0.0154 - val_loss: 0.0267
# Epoch 25/80
# 3/3 [==============================] - 0s 9ms/step - loss: 0.0153 - val_loss: 0.0261
# Epoch 26/80
# 3/3 [==============================] - 0s 9ms/step - loss: 0.0146 - val_loss: 0.0257
# Epoch 27/80
# 3/3 [==============================] - 0s 9ms/step - loss: 0.0147 - val_loss: 0.0255
# Epoch 28/80
# 3/3 [==============================] - 0s 9ms/step - loss: 0.0144 - val_loss: 0.0254
# Epoch 29/80
# 3/3 [==============================] - 0s 9ms/step - loss: 0.0143 - val_loss: 0.0252
# Epoch 30/80
# 3/3 [==============================] - 0s 9ms/step - loss: 0.0143 - val_loss: 0.0249
# Epoch 31/80
# 3/3 [==============================] - 0s 8ms/step - loss: 0.0139 - val_loss: 0.0248
# Epoch 32/80
# 3/3 [==============================] - 0s 10ms/step - loss: 0.0137 - val_loss: 0.0246
# Epoch 33/80
# 3/3 [==============================] - 0s 9ms/step - loss: 0.0137 - val_loss: 0.0246
# Epoch 34/80
# 3/3 [==============================] - 0s 9ms/step - loss: 0.0136 - val_loss: 0.0243
# Epoch 35/80
# 3/3 [==============================] - 0s 8ms/step - loss: 0.0134 - val_loss: 0.0241
# Epoch 36/80
# 3/3 [==============================] - 0s 9ms/step - loss: 0.0133 - val_loss: 0.0240
# Epoch 37/80
# 3/3 [==============================] - 0s 9ms/step - loss: 0.0131 - val_loss: 0.0238
# Epoch 38/80
# 3/3 [==============================] - 0s 10ms/step - loss: 0.0131 - val_loss: 0.0237
# Epoch 39/80
# 3/3 [==============================] - 0s 9ms/step - loss: 0.0132 - val_loss: 0.0235
# Epoch 40/80
# 3/3 [==============================] - 0s 9ms/step - loss: 0.0127 - val_loss: 0.0234
# Epoch 41/80
# 3/3 [==============================] - 0s 9ms/step - loss: 0.0127 - val_loss: 0.0233
# Epoch 42/80
# 3/3 [==============================] - 0s 9ms/step - loss: 0.0127 - val_loss: 0.0230
# Epoch 43/80
# 3/3 [==============================] - 0s 8ms/step - loss: 0.0126 - val_loss: 0.0229
# Epoch 44/80
# 3/3 [==============================] - 0s 10ms/step - loss: 0.0123 - val_loss: 0.0229
# Epoch 45/80
# 3/3 [==============================] - 0s 9ms/step - loss: 0.0122 - val_loss: 0.0229
# Epoch 46/80
# 3/3 [==============================] - 0s 9ms/step - loss: 0.0125 - val_loss: 0.0225
# Epoch 47/80
# 3/3 [==============================] - 0s 8ms/step - loss: 0.0120 - val_loss: 0.0224
# Epoch 48/80
# 3/3 [==============================] - 0s 9ms/step - loss: 0.0120 - val_loss: 0.0225
# Epoch 49/80
# 3/3 [==============================] - 0s 9ms/step - loss: 0.0118 - val_loss: 0.0221
# Epoch 50/80
# 3/3 [==============================] - 0s 9ms/step - loss: 0.0116 - val_loss: 0.0220
# Epoch 51/80
# 3/3 [==============================] - 0s 10ms/step - loss: 0.0116 - val_loss: 0.0219
# Epoch 52/80
# 3/3 [==============================] - 0s 10ms/step - loss: 0.0118 - val_loss: 0.0220
# Epoch 53/80
# 3/3 [==============================] - 0s 9ms/step - loss: 0.0114 - val_loss: 0.0216
# Epoch 54/80
# 3/3 [==============================] - 0s 13ms/step - loss: 0.0115 - val_loss: 0.0215
# Epoch 55/80
# 3/3 [==============================] - 0s 9ms/step - loss: 0.0116 - val_loss: 0.0214
# Epoch 56/80
# 3/3 [==============================] - 0s 10ms/step - loss: 0.0117 - val_loss: 0.0214
# Epoch 57/80
# 3/3 [==============================] - 0s 9ms/step - loss: 0.0112 - val_loss: 0.0216
# Epoch 58/80
# 3/3 [==============================] - 0s 9ms/step - loss: 0.0111 - val_loss: 0.0212
# Epoch 59/80
# 3/3 [==============================] - 0s 9ms/step - loss: 0.0108 - val_loss: 0.0210
# Epoch 60/80
# 3/3 [==============================] - 0s 9ms/step - loss: 0.0112 - val_loss: 0.0208
# Epoch 61/80
# 3/3 [==============================] - 0s 9ms/step - loss: 0.0105 - val_loss: 0.0211
# Epoch 62/80
# 3/3 [==============================] - 0s 9ms/step - loss: 0.0110 - val_loss: 0.0207
# Epoch 63/80
# 3/3 [==============================] - 0s 8ms/step - loss: 0.0111 - val_loss: 0.0206
# Epoch 64/80
# 3/3 [==============================] - 0s 9ms/step - loss: 0.0104 - val_loss: 0.0209
# Epoch 65/80
# 3/3 [==============================] - 0s 9ms/step - loss: 0.0108 - val_loss: 0.0206
# Epoch 66/80
# 3/3 [==============================] - 0s 9ms/step - loss: 0.0111 - val_loss: 0.0207
# Epoch 67/80
# 3/3 [==============================] - 0s 9ms/step - loss: 0.0107 - val_loss: 0.0206
# Epoch 68/80
# 3/3 [==============================] - 0s 8ms/step - loss: 0.0106 - val_loss: 0.0201
# Epoch 69/80
# 3/3 [==============================] - 0s 9ms/step - loss: 0.0102 - val_loss: 0.0201
# Epoch 70/80
# 3/3 [==============================] - 0s 8ms/step - loss: 0.0100 - val_loss: 0.0199
# Epoch 71/80
# 3/3 [==============================] - 0s 9ms/step - loss: 0.0100 - val_loss: 0.0199
# Epoch 72/80
# 3/3 [==============================] - 0s 9ms/step - loss: 0.0100 - val_loss: 0.0199
# Epoch 73/80
# 3/3 [==============================] - 0s 8ms/step - loss: 0.0099 - val_loss: 0.0198
# Epoch 74/80
# 3/3 [==============================] - 0s 9ms/step - loss: 0.0099 - val_loss: 0.0197
# Epoch 75/80
# 3/3 [==============================] - 0s 9ms/step - loss: 0.0098 - val_loss: 0.0197
# Epoch 76/80
# 3/3 [==============================] - 0s 8ms/step - loss: 0.0098 - val_loss: 0.0196
# Epoch 77/80
# 3/3 [==============================] - 0s 8ms/step - loss: 0.0098 - val_loss: 0.0196
# Epoch 78/80
# 3/3 [==============================] - 0s 8ms/step - loss: 0.0099 - val_loss: 0.0194
# Epoch 79/80
# 3/3 [==============================] - 0s 9ms/step - loss: 0.0097 - val_loss: 0.0194
# Epoch 80/80
# 3/3 [==============================] - 0s 9ms/step - loss: 0.0105 - val_loss: 0.0194

# %%
# Plot loss per iteration
plt.plot(r.history['loss'], label='loss')
plt.plot(r.history['val_loss'], label='val_loss')
plt.legend()

# %%
# "Wrong" forecast using true targets
validation_target = Y[-N//2:]
validation_predictions = []

# input of first vlidation input
i = -N//2

while len(validation_predictions) < len(validation_target):
  p = model.predict(X[i].reshape(1, -1))[0,0] # 1x1 array -> scalar
  i += 1

  # update the predictions list
  validation_predictions.append(p)

# %%
plt.plot(validation_target, label='forecast_target')
plt.plot(validation_predictions, label='forecast_prediction')
plt.legend()

# %%
# Forecast future values (use only self-predictions for making future predictions)
validation_target = Y[-N//2:]
validation_predictions = []

# last train input
last_x = X[-N//2] # 1-D array of length T
while len(validation_predictions) < len(validation_target):
  p = model.predict(last_x.reshape(1, -1))[0,0] # 1x1 array -> scalar

  # update the predictions list
  validation_predictions.append(p)

  # make the new input
  last_x = np.roll(last_x, -1)
  last_x[-1] = p

# %%
plt.plot(validation_target, label='forecast_target')
plt.plot(validation_predictions, label='forecast_prediction')
plt.legend()
