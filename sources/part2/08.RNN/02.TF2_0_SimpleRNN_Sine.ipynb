# %%
from tensorflow.keras.layers import Input, SimpleRNN, Dense, Flatten
from tensorflow.keras.models import Model
from tensorflow.keras.optimizers import SGD, Adam

import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
# make the original data (확인용, 예시)
series = np.sin(0.1 * np.arange(200))

# plot it
plt.plot(series)
plt.show()

# %%
# make the original data (노이즈 추가)
series = np.sin(0.1 * np.arange(200)) + np.random.randn(200) * 0.1

# plot it
plt.plot(series)
plt.show()

# %%
### build the dataset
# let's see if we can use T pas values to predict the next value
T =10
X = []
Y = []
for t in range(len(series) - T):
  x = series[t:t+T]
  X.append(x)
  y = series[t+T]
  Y.append(y)

np.array(X).shape
# Out:
# (190, 10)

# %%
X = np.array(X).reshape(-1, T, 1) # Now the data should be N x T x D
Y = np.array(Y)
N = len(X)
print("X.shape:", X.shape, ", Y.shape:", Y.shape)
# Out:
# X.shape: (190, 10, 1) , Y.shape: (190,)

# %%
### try autoregressive RNN model
i= Input(shape=(T, 1))
# x = SimpleRNN(5, activation='relu')(i)
# x = SimpleRNN(5, activation=None)(i)
# x = SimpleRNN(5)(i)
x = SimpleRNN(5, activation='relu')(i)
x = Dense(1)(x)
model = Model(i, x)
model.compile(
    loss='mse',
    optimizer=Adam(lr=0.1),
)

model.summary()
# Out:
# Model: "model_1"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_2 (InputLayer)        [(None, 10, 1)]           0
#
#  simple_rnn_1 (SimpleRNN)    (None, 5)                 35
#
#  dense_1 (Dense)             (None, 1)                 6
#
# =================================================================
# Total params: 41
# Trainable params: 41
# Non-trainable params: 0
# _________________________________________________________________

# %%
# train the RNN
r = model.fit(
    X[:-N//2], Y[:-N//2],
    epochs=80,
    validation_data=(X[-N//2:], Y[-N//2:]),
)
# Out:
# Epoch 1/80
# 3/3 [==============================] - 1s 83ms/step - loss: 0.8853 - val_loss: 0.7728
# Epoch 2/80
# 3/3 [==============================] - 0s 14ms/step - loss: 0.6242 - val_loss: 0.6103
# Epoch 3/80
# 3/3 [==============================] - 0s 15ms/step - loss: 0.4994 - val_loss: 0.4624
# Epoch 4/80
# 3/3 [==============================] - 0s 12ms/step - loss: 0.4128 - val_loss: 0.3691
# Epoch 5/80
# 3/3 [==============================] - 0s 13ms/step - loss: 0.3387 - val_loss: 0.2615
# Epoch 6/80
# 3/3 [==============================] - 0s 14ms/step - loss: 0.2415 - val_loss: 0.1480
# Epoch 7/80
# 3/3 [==============================] - 0s 13ms/step - loss: 0.1286 - val_loss: 0.0638
# Epoch 8/80
# 3/3 [==============================] - 0s 13ms/step - loss: 0.0502 - val_loss: 0.0519
# Epoch 9/80
# 3/3 [==============================] - 0s 53ms/step - loss: 0.0697 - val_loss: 0.0980
# Epoch 10/80
# 3/3 [==============================] - 0s 31ms/step - loss: 0.0992 - val_loss: 0.0974
# Epoch 11/80
# 3/3 [==============================] - 0s 18ms/step - loss: 0.0759 - val_loss: 0.0572
# Epoch 12/80
# 3/3 [==============================] - 0s 17ms/step - loss: 0.0481 - val_loss: 0.0464
# Epoch 13/80
# 3/3 [==============================] - 0s 15ms/step - loss: 0.0451 - val_loss: 0.0587
# Epoch 14/80
# 3/3 [==============================] - 0s 15ms/step - loss: 0.0556 - val_loss: 0.0623
# Epoch 15/80
# 3/3 [==============================] - 0s 14ms/step - loss: 0.0525 - val_loss: 0.0499
# Epoch 16/80
# 3/3 [==============================] - 0s 14ms/step - loss: 0.0416 - val_loss: 0.0414
# Epoch 17/80
# 3/3 [==============================] - 0s 13ms/step - loss: 0.0388 - val_loss: 0.0431
# Epoch 18/80
# 3/3 [==============================] - 0s 16ms/step - loss: 0.0401 - val_loss: 0.0455
# Epoch 19/80
# 3/3 [==============================] - 0s 17ms/step - loss: 0.0402 - val_loss: 0.0430
# Epoch 20/80
# 3/3 [==============================] - 0s 15ms/step - loss: 0.0365 - val_loss: 0.0384
# Epoch 21/80
# 3/3 [==============================] - 0s 14ms/step - loss: 0.0344 - val_loss: 0.0396
# Epoch 22/80
# 3/3 [==============================] - 0s 14ms/step - loss: 0.0350 - val_loss: 0.0391
# Epoch 23/80
# 3/3 [==============================] - 0s 16ms/step - loss: 0.0340 - val_loss: 0.0366
# Epoch 24/80
# 3/3 [==============================] - 0s 17ms/step - loss: 0.0318 - val_loss: 0.0365
# Epoch 25/80
# 3/3 [==============================] - 0s 15ms/step - loss: 0.0325 - val_loss: 0.0367
# Epoch 26/80
# 3/3 [==============================] - 0s 14ms/step - loss: 0.0316 - val_loss: 0.0344
# Epoch 27/80
# 3/3 [==============================] - 0s 16ms/step - loss: 0.0303 - val_loss: 0.0338
# Epoch 28/80
# 3/3 [==============================] - 0s 16ms/step - loss: 0.0306 - val_loss: 0.0337
# Epoch 29/80
# 3/3 [==============================] - 0s 16ms/step - loss: 0.0296 - val_loss: 0.0328
# Epoch 30/80
# 3/3 [==============================] - 0s 19ms/step - loss: 0.0292 - val_loss: 0.0323
# Epoch 31/80
# 3/3 [==============================] - 0s 17ms/step - loss: 0.0287 - val_loss: 0.0318
# Epoch 32/80
# 3/3 [==============================] - 0s 17ms/step - loss: 0.0285 - val_loss: 0.0311
# Epoch 33/80
# 3/3 [==============================] - 0s 17ms/step - loss: 0.0280 - val_loss: 0.0308
# Epoch 34/80
# 3/3 [==============================] - 0s 16ms/step - loss: 0.0276 - val_loss: 0.0308
# Epoch 35/80
# 3/3 [==============================] - 0s 13ms/step - loss: 0.0280 - val_loss: 0.0305
# Epoch 36/80
# 3/3 [==============================] - 0s 13ms/step - loss: 0.0272 - val_loss: 0.0299
# Epoch 37/80
# 3/3 [==============================] - 0s 16ms/step - loss: 0.0277 - val_loss: 0.0296
# Epoch 38/80
# 3/3 [==============================] - 0s 17ms/step - loss: 0.0266 - val_loss: 0.0305
# Epoch 39/80
# 3/3 [==============================] - 0s 19ms/step - loss: 0.0271 - val_loss: 0.0302
# Epoch 40/80
# 3/3 [==============================] - 0s 16ms/step - loss: 0.0273 - val_loss: 0.0290
# Epoch 41/80
# 3/3 [==============================] - 0s 17ms/step - loss: 0.0269 - val_loss: 0.0290
# Epoch 42/80
# 3/3 [==============================] - 0s 14ms/step - loss: 0.0261 - val_loss: 0.0293
# Epoch 43/80
# 3/3 [==============================] - 0s 15ms/step - loss: 0.0263 - val_loss: 0.0292
# Epoch 44/80
# 3/3 [==============================] - 0s 15ms/step - loss: 0.0258 - val_loss: 0.0286
# Epoch 45/80
# 3/3 [==============================] - 0s 15ms/step - loss: 0.0265 - val_loss: 0.0286
# Epoch 46/80
# 3/3 [==============================] - 0s 14ms/step - loss: 0.0257 - val_loss: 0.0286
# Epoch 47/80
# 3/3 [==============================] - 0s 15ms/step - loss: 0.0257 - val_loss: 0.0287
# Epoch 48/80
# 3/3 [==============================] - 0s 15ms/step - loss: 0.0256 - val_loss: 0.0283
# Epoch 49/80
# 3/3 [==============================] - 0s 18ms/step - loss: 0.0257 - val_loss: 0.0282
# Epoch 50/80
# 3/3 [==============================] - 0s 18ms/step - loss: 0.0260 - val_loss: 0.0284
# Epoch 51/80
# 3/3 [==============================] - 0s 16ms/step - loss: 0.0268 - val_loss: 0.0305
# Epoch 52/80
# 3/3 [==============================] - 0s 18ms/step - loss: 0.0257 - val_loss: 0.0281
# Epoch 53/80
# 3/3 [==============================] - 0s 14ms/step - loss: 0.0263 - val_loss: 0.0286
# Epoch 54/80
# 3/3 [==============================] - 0s 16ms/step - loss: 0.0259 - val_loss: 0.0289
# Epoch 55/80
# 3/3 [==============================] - 0s 16ms/step - loss: 0.0266 - val_loss: 0.0293
# Epoch 56/80
# 3/3 [==============================] - 0s 15ms/step - loss: 0.0257 - val_loss: 0.0276
# Epoch 57/80
# 3/3 [==============================] - 0s 14ms/step - loss: 0.0254 - val_loss: 0.0279
# Epoch 58/80
# 3/3 [==============================] - 0s 13ms/step - loss: 0.0251 - val_loss: 0.0278
# Epoch 59/80
# 3/3 [==============================] - 0s 15ms/step - loss: 0.0251 - val_loss: 0.0276
# Epoch 60/80
# 3/3 [==============================] - 0s 16ms/step - loss: 0.0261 - val_loss: 0.0274
# Epoch 61/80
# 3/3 [==============================] - 0s 16ms/step - loss: 0.0274 - val_loss: 0.0294
# Epoch 62/80
# 3/3 [==============================] - 0s 15ms/step - loss: 0.0257 - val_loss: 0.0273
# Epoch 63/80
# 3/3 [==============================] - 0s 13ms/step - loss: 0.0265 - val_loss: 0.0272
# Epoch 64/80
# 3/3 [==============================] - 0s 12ms/step - loss: 0.0259 - val_loss: 0.0305
# Epoch 65/80
# 3/3 [==============================] - 0s 14ms/step - loss: 0.0270 - val_loss: 0.0270
# Epoch 66/80
# 3/3 [==============================] - 0s 14ms/step - loss: 0.0253 - val_loss: 0.0278
# Epoch 67/80
# 3/3 [==============================] - 0s 13ms/step - loss: 0.0247 - val_loss: 0.0282
# Epoch 68/80
# 3/3 [==============================] - 0s 12ms/step - loss: 0.0266 - val_loss: 0.0281
# Epoch 69/80
# 3/3 [==============================] - 0s 12ms/step - loss: 0.0251 - val_loss: 0.0272
# Epoch 70/80
# 3/3 [==============================] - 0s 13ms/step - loss: 0.0253 - val_loss: 0.0281
# Epoch 71/80
# 3/3 [==============================] - 0s 13ms/step - loss: 0.0254 - val_loss: 0.0285
# Epoch 72/80
# 3/3 [==============================] - 0s 12ms/step - loss: 0.0247 - val_loss: 0.0272
# Epoch 73/80
# 3/3 [==============================] - 0s 11ms/step - loss: 0.0254 - val_loss: 0.0269
# Epoch 74/80
# 3/3 [==============================] - 0s 12ms/step - loss: 0.0252 - val_loss: 0.0291
# Epoch 75/80
# 3/3 [==============================] - 0s 13ms/step - loss: 0.0254 - val_loss: 0.0269
# Epoch 76/80
# 3/3 [==============================] - 0s 12ms/step - loss: 0.0254 - val_loss: 0.0277
# Epoch 77/80
# 3/3 [==============================] - 0s 14ms/step - loss: 0.0253 - val_loss: 0.0281
# Epoch 78/80
# 3/3 [==============================] - 0s 14ms/step - loss: 0.0256 - val_loss: 0.0276
# Epoch 79/80
# 3/3 [==============================] - 0s 13ms/step - loss: 0.0244 - val_loss: 0.0269
# Epoch 80/80
# 3/3 [==============================] - 0s 13ms/step - loss: 0.0249 - val_loss: 0.0271

# %%
# Plot loss per iteration
plt.plot(r.history['loss'], label='loss')
plt.plot(r.history['val_loss'], label='val_loss')
plt.legend()

# %%
# "Wrong" forecast using true targets
validation_target = Y[-N//2:]
validation_predictions = []

# input of first vlidation input
i = -N//2

while len(validation_predictions) < len(validation_target):
  p = model.predict(X[i].reshape(1, -1, 1))[0,0] # 1x1 array -> scalar
  i += 1

  # update the predictions list
  validation_predictions.append(p)

# %%
plt.plot(validation_target, label='forecast_target')
plt.plot(validation_predictions, label='forecast_prediction')
plt.legend()

# %%
# Forecast future values (use only self-predictions for making future predictions)
validation_target = Y[-N//2:]
validation_predictions = []

# last train input
last_x = X[-N//2] # 1-D array of length T

while len(validation_predictions) < len(validation_target):
    p = model.predict(last_x.reshape(1, -1, 1))[0,0] # 1x1 array -> scalar

    # update the predictions list
    validation_predictions.append(p)

    # make the new input
    last_x = np.roll(last_x, -1)
    print(last_x)
    last_x[-1] = p

# %%
plt.plot(validation_target, label='forecast_target')
plt.plot(validation_predictions, label='forecast_prediction')
plt.legend()
